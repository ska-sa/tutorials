# %%
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %% [markdown]
# What is the difference between a equatorial mount antenna and an az-el mount antenna?

# %% [markdown]
# Which would be better for a transit survey of a source?

# %% [markdown]
# We will simulate a drift scan across a number of sources. Change the N parameter below until you can clearly see the 5 signals from the sources hidden in the noise. Write a short paragraph about what you think is being simuated here and any comments about the 5 signals and how well you can see them.

# %%
N = 1  # < ---- Increase this number to any integer greater than 1
M = 1000
A = 1
ra = arange(M) * 100./M
signal = zeros((N,M))
seed(8)
signal1 = exp(-((ra-50.)/10.)**2)
signal2 = exp(-((ra-20.)/10.)**2)
signal3 = exp(-((ra-25.)/10.)**2)
signal4 = exp(-((ra-80.)/3)**2)
signal5 = 0.5*exp(-((ra-10.)/3.)**2)
for i in range(N):
    signal6 = A*randn(M)
    signal7 = signal1+signal2+signal3+signal4+signal5+signal6
    signal[i,:] = signal7
plot(ra,signal.mean(axis=0))

# %% [markdown]
# List the transmit frequecies for the following radio services
# * FM radio
# * DSTV
# * GPS L1
# * Voyager spacecraft uplink and downlink

# %% [markdown]
# What size dipole would you use for each of the signals listed above?

# %% [markdown]
# Define the term resoance. How does this apply to electrical circuits?

# %% [markdown]
# Does the size of the dish have anything to do with the operating frequency?

# %% [markdown]
# Give all the pro's and con's for making telescopes with bigger dishes?

# %% [markdown]
# The blue vectors shown below are the Poynting vector. What is the Poynting vector and what are the other vectors shown?
#
# ![DC Circuit](https://upload.wikimedia.org/wikipedia/commons/thumb/8/82/Poynting_vectors_of_DC_circuit.svg/500px-Poynting_vectors_of_DC_circuit.svg.png)
