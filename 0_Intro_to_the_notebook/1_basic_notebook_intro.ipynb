# %% [raw]
# Lets create a title

# %% [markdown]
# And write some text...
#
# Maybe use some markdown:
#
# * for various reasons,
# * such as bullet points

# %% [markdown]
# Let's embedd a picture:

# %%
# !ls
# Out:
# intro.ipynb          ska_logo_rgb_med.jpg

# %%
![img](ska_logo_rgb_med.jpg)

# %%
LaTeX!

${\alpha \beta \gamma}^2$

# %%
print "hello world!"
# Out:
# hello world!

# %%
import numpy as np

# %%
x = np.arange(0.,10.,0.1)

# %%
y = 2.0*np.sin(1.5*x)

# %%
plot(x,y)

# %%
from IPython.html.widgets import interact

# %%
def plot_scaled_sin(a,c):
    plot(x,y)
    
    y_interact = c*np.sin(a*x)
    plot(x,y_interact)

# %%
interact(plot_scaled_sin, a=(0.,3.,0.1), c=(0.5,10.,0.5));
