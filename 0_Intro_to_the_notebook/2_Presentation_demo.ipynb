# %% [markdown]
# # My presentation title

# %% [markdown]
# by Laura Richter

# %%
import numpy as np

# %% [markdown]
# ###Some Markup notes###
# About maths. Or something
#
# Maybe with some bullet points:
#
# * A list
# * Of notes
# * Of some sort
#
# Perhaps also including a [wiki article](http://en.wikipedia.org/wiki/Brown_bear).

# %% [markdown]
# ###More markdown notes###
#
# Perhaps a video:

# %%
from IPython.display import YouTubeVideo
YouTubeVideo("8UVNT4wvIGY")
# Out:
#         <iframe
#             width="400"
#             height=300"
#             src="https://www.youtube.com/embed/8UVNT4wvIGY"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>

# %%
x = np.arange(0.,10.,0.1)
y = np.sin(x)
plot(x,y)

# %%
ynoise = y + np.random.randn(len(y))/5.
plot(x,y)
plot(x,ynoise)

# %% [markdown]
# Some notes about how we calculated the noise...
#
# Maybe with some LaTeX symbols:
# $\cos(\theta) + i \sin(\theta)$

# %% [markdown]
# #### The end!
